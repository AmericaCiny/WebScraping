# %% [markdown]
# #### DDR Assignment 6.2

# %%
from pymongo import MongoClient

from bson import decode_all
from bson.json_util import dumps
import pprint

# %%
Mongoserver = MongoClient("mongodb+srv://tu1242186698:Tu1242186698@cluster0.nfm24mv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

# %%
#client = MongoClient("mongodb://host:27017/")
database = Mongoserver["samples_pokemon"]
collection = database["samples_pokemon"]

query = {}
query["candy_count"] = {
    u"$gt": 100.0
}


cursor = collection.find(query)
for doc in cursor:
    print(doc)
# Out:
# {'_id': ObjectId('58f56171ee9d4bd5e610d6c4'), 'id': 129.0, 'num': '129', 'name': 'Magikarp', 'img': 'http://www.serebii.net/pokemongo/pokemon/129.png', 'type': ['Water'], 'height': '0.89 m', 'weight': '10.0 kg', 'candy': 'Magikarp Candy', 'candy_count': 400.0, 'egg': '2 km', 'spawn_chance': 4.78, 'avg_spawns': 478.0, 'spawn_time': '14:26', 'multipliers': [10.1, 11.8], 'weaknesses': ['Electric', 'Grass'], 'next_evolution': [{'num': '130', 'name': 'Gyarados'}]}

# %%
candy_count = 2 * 12 + 18 #DOB 12/18

results = collection.find({"candy_count": {"$gte": candy_count}}, {"_id":1,"name":1})

# Print out the results
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('58f56171ee9d4bd5e610d64e'), 'name': 'Metapod'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d66a'), 'name': 'Jigglypuff'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d671'), 'name': 'Paras'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d68b'), 'name': 'Tentacool'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d658'), 'name': 'Spearow'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d683'), 'name': 'Kadabra'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d68e'), 'name': 'Graveler'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d673'), 'name': 'Venonat'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d668'), 'name': 'Vulpix'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d6a7'), 'name': 'Voltorb'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d6b0'), 'name': 'Koffing'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d6b7'), 'name': 'Horsea'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d677'), 'name': 'Meowth'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d699'), 'name': 'Seel'}
# ...

# %% [markdown]
# Write code (Python or Java) to query and print to screen all Pokémon character “name”s (and “_id” but not the entire document) with num = 2*month or num = day of your birthday  (e.g., my birthday is 2/12 and I have to query num = 4 or num = 12).

# %%
num_month = str(2*12).zfill(3)
num_day = str(18).zfill(3)

results = collection.find({"$or": [{"num": str(num_month)}, {"num": str(num_day)}]}, {"name": 1, "_id": 1})

# Print out the results
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('58f56171ee9d4bd5e610d65b'), 'name': 'Arbok'}
# {'_id': ObjectId('58f56171ee9d4bd5e610d655'), 'name': 'Pidgeot'}

# %% [markdown]
# Write code (Python or Java) to query and print to screen all Crunchbase company “name”s (and “_id” but not the entire document) that have the string “cloud” in their “tag_list”.

# %%
database = Mongoserver.crunchbase
crunchbase_db = database.crunchbase_database
query = {}
cursor = crunchbase_db.find(query)
for doc in cursor:
    print(doc)
# Out:
# {'_id': ObjectId('52cdef7d4bab8bd67529899d'), 'name': 'Pepsmedia', 'permalink': 'pepsmedia', 'crunchbase_url': 'http://www.crunchbase.com/company/pepsmedia', 'homepage_url': None, 'blog_url': None, 'blog_feed_url': None, 'twitter_username': None, 'category_code': None, 'number_of_employees': None, 'founded_year': None, 'founded_month': None, 'founded_day': None, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': '', 'alias_list': None, 'email_address': None, 'phone_number': None, 'description': None, 'created_at': 'Tue May 06 00:13:32 UTC 2008', 'updated_at': 'Thu Aug 05 16:36:20 UTC 2010', 'overview': '<p>Pepsmedia is an experienced social media marketing and blog development agency based in Cambridge, UK.</p>\n\n<p>We help you discover your online community, start a conversation with your customers and produce successful creative online marketing campaigns.</p>\n\n<p>Our team provides a full suite of social media consultan
# ...

# %% [markdown]
# Write code (Python or Java) to query and print to screen all Crunchbase company “name”s and “twitter_username” (and “_id” but not the entire document) that (i) were founded between 2000 and 2010 (including 2000 and 2010), or (ii) email address is ending in “@gmail.com”.

# %%
# Write a query using regex and print out name and id only
results = crunchbase_db.find({"tag_list": {"$regex": "cloud"}}, {"name": 1, "_id": 1,"email_address":1})

# Print out the results
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('52cdef7e4bab8bd67529b289'), 'name': 'Ekartha', 'email_address': 'sales@ekartha.com'}
# {'_id': ObjectId('52cdef7d4bab8bd675298ebf'), 'name': 'Faulkner Technologies', 'email_address': 'info@faulknertechnologies.com'}
# {'_id': ObjectId('52cdef7e4bab8bd67529a6aa'), 'name': 'EVault', 'email_address': 'concierge@evault.com'}
# {'_id': ObjectId('52cdef7e4bab8bd67529bbd0'), 'name': 'CodeLathe', 'email_address': 'support@codelathe.com'}
# {'_id': ObjectId('52cdef7e4bab8bd67529adeb'), 'name': 'TimeXchange', 'email_address': 'joep@actustech.com'}
# {'_id': ObjectId('52cdef7c4bab8bd675298514'), 'name': 'Zuora', 'email_address': 'info@zuora.com'}
# {'_id': ObjectId('52cdef7d4bab8bd675299555'), 'name': 'Purewire', 'email_address': 'info@purewire.com'}
# {'_id': ObjectId('52cdef7c4bab8bd675297ee1'), 'name': 'Cloudant', 'email_address': 'info@cloudant.com'}
# {'_id': ObjectId('52cdef7e4bab8bd67529b3df'), 'name': 'Clustrix', 'email_address': 'info@clustrix.com'}
# ...

# %%
results = crunchbase_db.find({"$or": [{"founded_year": {"$gte": 2000, "$lte": 2010}}, {"email_address": {"$regex": "@gmail\.com$"}}]}, {"name": 1, "twitter_username": 1, "_id": 1})

for result in results:
    print(result)
# Out:
# {'_id': ObjectId('52cdef7e4bab8bd67529b289'), 'name': 'Ekartha', 'twitter_username': ''}
# {'_id': ObjectId('52cdef7d4bab8bd67529a224'), 'name': 'Nth Penguin', 'twitter_username': None}
# {'_id': ObjectId('52cdef7e4bab8bd67529ab6a'), 'name': 'BrickHouse Security', 'twitter_username': 'BrickHouseSecur'}
# {'_id': ObjectId('52cdef7d4bab8bd675298cfa'), 'name': 'Mobile Rider', 'twitter_username': 'mobilerider'}
# {'_id': ObjectId('52cdef7d4bab8bd675299c07'), 'name': 'Nealite', 'twitter_username': 'nealite'}
# {'_id': ObjectId('52cdef7d4bab8bd675299618'), 'name': 'Sendible', 'twitter_username': 'sendible'}
# {'_id': ObjectId('52cdef7e4bab8bd67529b8ba'), 'name': 'PowerMand', 'twitter_username': ''}
# {'_id': ObjectId('52cdef7d4bab8bd67529915b'), 'name': 'Unisfair', 'twitter_username': 'Unisfair'}
# {'_id': ObjectId('52cdef7c4bab8bd675298151'), 'name': 'Viadeo', 'twitter_username': 'viadeo'}
# {'_id': ObjectId('52cdef7c4bab8bd675297fc5'), 'name': 'MuseStorm', 'twitter_username': ''}
# ...
